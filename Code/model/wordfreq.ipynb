# %%
import pandas as pd
import re 
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec

# %%
review = pd.read_csv("review_cleaned.csv")[:100]
review['text'] = [i.replace('  ',' ').replace('  ', ' ') for i in review['text']]

# %%
full_text = ''.join(review['text'])
word_tokens = word_tokenize(full_text)
tokens = list()
for word in word_tokens:
    if word.isalpha():
        tokens.append(word)
token_dist = FreqDist(tokens)
porter = PorterStemmer()
stemmed_tokens =[porter.stem(word) for word in tokens]
stemmed_token_dist = FreqDist(stemmed_tokens)
stemmed_dist = pd.DataFrame(stemmed_token_dist.most_common(20),columns=['Word', 'Frequency'])
vect = CountVectorizer(ngram_range=(2,2))
bigrams = vect.fit_transform(review['text'])
bigram_df = pd.DataFrame(bigrams.toarray(), columns=vect.get_feature_names())
bigram_frequency = pd.DataFrame(bigram_df.sum(axis=0)).reset_index()
bigram_frequency.columns = ['bigram', 'frequency']
bigram_frequency = bigram_frequency.sort_values(by='frequency', ascending=False).head(20)

# %%
bigram_frequency
# Out:
#                bigram  frequency
# 3733      pulled pork          9
# 3802      really good          8
# 1976          go back          7
# 2823       mac cheese          6
# 2042        good food          6
# 3262      onion rings          6
# 3676      pretty good          6
# 652        burnt ends          6
# 2691  liquid nitrogen          5
# 4666     sweet potato          5
# 2576       last night          5
# 1703      flip burger          5
# 361          bbq pork          4
# 3917       ribs great          4
# 3678      pretty much          4
# 4216    service great          4
# 1818       fried okra          4
# 1811    fried chicken          4
# 1803     french fries          4
# 3069         must try          4
